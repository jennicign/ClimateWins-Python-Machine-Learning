# %% [markdown]
# # Exercise 2.1 Dendrograms using Principal Components Dataframe

# %% [markdown]
# ### Contents:

# %% [markdown]
# #### 01. Importing Libraries and Data
# #### 02. Creating Dendrograms with Prinicpal Components Data

# %% [markdown]
# ## 01. Importing Libraries and Data

# %%
# Import libraries

import pandas as pd
import numpy as np
import seaborn as sns
import os
import operator
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from matplotlib.pyplot import figure
from scipy.cluster.hierarchy import dendrogram, linkage, fcluster

# %%
# Set option to ensure charts are displayed inline in the notebook

# %matplotlib inline

# %%
# Set option to display max number of columns

pd.set_option('display.max_columns', None)

# %%
# Define path for importing the data

path = r'C:\Users\jenci\Documents\Data Analytics\Data Analytics\Machine Learning\Achievement 2\Achievment Project'

# %%
df = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'principal_components_df_2010.csv'))

# %% [markdown]
# ## 02. Creating Dendrograms with Principal Components Data

# %% [markdown]
# > The data being used was wrangled and scaled in previous step for hierarchical clustering.

# %%
# Create dendrogram (single method) 
distance_single = linkage(df, method="single")

plt.figure(figsize=(18,6))
dendrogram(distance_single, leaf_rotation=90)
plt.xlabel('Index')
plt.ylabel('Distance')
plt.suptitle("Dendrogram Single Method",fontsize=18)
plt.show()

# %%
# Create dendrogram (complete method)
distance_complete = linkage(df, method="complete")

plt.figure(figsize=(18,6))
dendrogram(distance_complete, leaf_rotation=90)
plt.xlabel('Index')
plt.ylabel('Distance')
plt.suptitle("Dendrogram Complete Method",fontsize=18)
plt.show()

# %%
# Create dendrogram (average method)
distance_average = linkage(df, method="average")

plt.figure(figsize=(18,6))
dendrogram(distance_average, leaf_rotation=90)
plt.xlabel('Index')
plt.ylabel('Distance')
plt.suptitle("Dendrogram Average Method",fontsize=18)
plt.show()

# %%
# Create dendrogram (ward method)
distance_ward = linkage(df, method="ward")

plt.figure(figsize=(18,6))
dendrogram(distance_ward, leaf_rotation=90)
plt.xlabel('Index')
plt.ylabel('Distance')
plt.suptitle("Dendrogram Ward Method",fontsize=18)
plt.show()
